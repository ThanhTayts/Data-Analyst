# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Yêu cầu 1

# %%
# Đọc bộ dữ liệu
df = pd.read_csv('D:\Desktop\Data_Analyst\Jupiter_Notebook_Pandas\Pandas\OnlineRetail.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# cho biết số dòng, số cột , # kiểu dữ liệu của các thuộc tính
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# #### Yêu cầu 2

# %%
# Tạo 1 cột tháng để dễ lọc dữ liệu

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df['Month'] = df['InvoiceDate'].dt.month
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Month
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     12
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     12
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12

# %%
# Câu điều kiện
# Tạo cột mới có tên quý –  ‘Previous’ nhận giá trị 1 nếu ngày lập hóa đơn nằm trong các tháng 1,2,3; 
# nhận giá trị 2 nếu ngày lập hóa đơn nằm trong các tháng 4,5,6; 
# nhận giá trị 3 nếu ngày lập hóa đơn nằm trong các tháng 7,8,9;  
# nhận giá trị 4 nếu ngày lập hóa đơn nằm trong các tháng 10,11,12;
# Cách 1
df['Previous'] = np.where(df['Month'].isin([1,2,3]), 1, np.where(df['Month'].isin([4,5,6]), 2, np.where(df['Month'].isin([7,8,9]), 3, 4)))
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Month  Previous
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     12         4
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     12         4
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4

# %%
# Cách 2
conditions = [((df['Month'] == 1) | (df['Month'] == 2) | (df['Month'] == 3)),
              ((df['Month'] == 4) | (df['Month'] == 5) | (df['Month'] == 6)),
                ((df['Month'] == 7) | (df['Month'] == 8) | (df['Month'] == 9)),
                ((df['Month'] == 10) | (df['Month'] == 11) | (df['Month'] == 12))]
choices = [1,2,3,4]
df['Previous_test'] = np.select(conditions, choices, default= None)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Month  Previous  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     12         4
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     12         4
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
#
#   Previous_test
# 0             4
# 1             4
# 2             4
# ...

# %%
# Kiểm tra xem đã lọc đúng chưa
df.groupby('Month')['Previous'].value_counts()
# Out:
# Month  Previous
# 1      1           35147
# 2      1           27707
# 3      1           36748
# 4      2           29916
# 5      2           37030
# 6      2           36874
# 7      3           39518
# 8      3           35284
# 9      3           50226
# 10     4           60742
# 11     4           84711
# 12     4           68006
# Name: Previous, dtype: int64

# %% [markdown]
# #### Yêu cầu 3

# %%
# Tạo một cột mới có tên ‘Amount’ có giá trị bằng Quantity * UnitPrice
df['Amount'] = df['Quantity'] * df['UnitPrice']
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Month  Previous  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     12         4
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     12         4
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
#
#   Previous_test  Amount
# 0             4   15.30
# 1             4   20.34
# ...

# %% [markdown]
# #### Yêu cầu 4

# %%
# Tạo cột mới ‘Discount’ nhận giá trị 10% nếu Country là ‘United Kingdom’ và thuộc quý 4, 5% nếu là ‘France’ ngược lại là 0%.
df['Discount'] = np.where((df['Country'] == 'United Kingdom') & (df['Previous'] == 4) ,0.1, np.where((df['Country'] == 'France') ,0.05, 0))

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Month  Previous  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     12         4
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     12         4
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
#
#   Previous_test  Amount  Discount
# 0             4   15.30       0.1
# ...

# %% [markdown]
# ##### Yều cầu 5

# %%
# Tạo cột mới ‘Total’ nhận giá trị bằng: Amount – Discount.
df['Total'] = df['Amount'] - df['Discount']
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Month  Previous  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     12         4
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     12         4
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12         4
#
#   Previous_test  Amount  Discount  Total
# ...
