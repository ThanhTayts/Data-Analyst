# %%
# import thư viện Pandas
import pandas as pd

# %% [markdown]
# ### 1. Đọc dữ liệu từ file csv

# %%
# Cách 1: Ghi tường minh các tham số
import pandas as pd
df=pd.read_csv('D:\Desktop\Data_Analyst\Jupiter_Notebook_Pandas\Pandas\FoodPrice_in_Turkey.csv') # đường dẫn tuyệt đối
# Hiển thị 5 dòng dữ liệu đầu tiên
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
# Cách 2: Không ghi tường minh các tham số
import pandas as pd
df=pd.read_csv('FoodPrice_in_Turkey.csv') # đường đẫn tương đối nếu cùng chung thư mục
# Hiển thị 5 dòng dữ liệu đầu tiên
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %% [markdown]
# ### 2. Đọc dữ liệu từ file excel

# %%
df=pd.read_excel('D:\Desktop\Data_Analyst\Jupiter_Notebook_Pandas\Pandas\house_price_dống-da.xlsx')
df.head()
# Out:
# D:\Anaconda\Anaconda_Setup\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                title  \
# 0  Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 1  Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2  Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 3  Bán nhà 6 tầng mới kinh doanh mặt ngõ 1194 Đườ...
# 4  Bán nhà mặt phố Thái Hà 70m2, 5 tầng, 4.5m mặt...
#
#                                              address  area    price  \
# 0  Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...  50.0  14700.0
# 1  Đường Tây Sơn, Phường Trung Liệt, Đống Đa, Hà...  35.0  12500.0
# 2  Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...  57.0   4200.0
# 3  Ngõ 1194, Đường Láng, Phường Láng Thượng, Đố...  62.0  11000.0
# 4   Phố Thái Hà, Phường Trung Liệt, Đống Đa, Hà Nội  70.0  36000.0
#
# ...

# %% [markdown]
# ### 3. Đọc dữ liệu từ file Json

# %%
df = pd.read_json('D:\Desktop\Data_Analyst\Jupiter_Notebook_Pandas\Pandas\OnlineRetail_new.json')
df.head()
# Out:
#       Quantity      InvoiceDate  UnitPrice
# 1000         1  12/1/2010 12:43       1.25
# 1001         1  12/1/2010 12:43       1.25
# 1002         1  12/1/2010 12:43       1.25
# 1003         1  12/1/2010 12:43       1.25
# 1004        12  12/1/2010 12:43       0.29

# %% [markdown]
# ### 4. Đọc dữ liệu từ file hdf5

# %%
df=pd.read_hdf('D:\Desktop\Data_Analyst\Jupiter_Notebook_Pandas\Pandas\OnlineRetail_new.h5')
df.head()
# Out:
#    InvoiceNo StockCode                      Description  Quantity  \
# 9     536367     84879    ASSORTED COLOUR BIRD ORNAMENT        32
# 26    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 9   12/1/2010 8:34       1.69     13047.0  United Kingdom
# 26  12/1/2010 8:45       3.75     12583.0          France
# 27  12/1/2010 8:45       3.75     12583.0          France
# 28  12/1/2010 8:45       3.75     12583.0          France
# 29  12/1/2010 8:45       0.85     12583.0          France

# %% [markdown]
# ### 5. Đọc dữ liệu từ file html

# %%
url = 'https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_in_North_America'
df = pd.read_html(url)
df[0].head()
# Out:
#    Flag        English short name            English long name  \
# 0   NaN  Antigua and Barbuda[n 1]          Antigua and Barbuda
# 1   NaN         Bahamas, The[n 1]  Commonwealth of The Bahamas
# 2   NaN             Barbados[n 1]                     Barbados
# 3   NaN          Belize[n 1][n 2]                       Belize
# 4   NaN               Canada[n 3]                       Canada
#
#           Domestic short name(s)     Capital               Currency  \
# 0   English: Antigua and Barbuda  St. John's  East Caribbean dollar
# 1               English: Bahamas      Nassau        Bahamian dollar
# 2              English: Barbados  Bridgetown       Barbadian dollar
# 3                English: Belize    Belmopan          Belize dollar
# 4  English: CanadaFrench: Canada      Ottawa        Canadian dollar
#
#    Population
# 0       97118
# 1      389482
# 2      287025
# 3      390353
# 4    35151728
