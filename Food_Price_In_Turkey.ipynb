# %%
# import thư viện
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# đọc dữ liệu
df = pd.read_csv('D:\Desktop\Data_Analyst\Jupiter_Notebook_Pandas\Pandas\FoodPrice_in_Turkey.csv')
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
df.tail()
# Out:
#       Place  ProductId              ProductName  UmId UmName  Month  Year  \
# 7376  Izmir        502  Cocoa (powder) - Retail     5     KG      8  2019
# 7377  Izmir        502  Cocoa (powder) - Retail     5     KG      9  2019
# 7378  Izmir        502  Cocoa (powder) - Retail     5     KG     10  2019
# 7379  Izmir        502  Cocoa (powder) - Retail     5     KG     11  2019
# 7380  Izmir        502  Cocoa (powder) - Retail     5     KG     12  2019
#
#         Price
# 7376  47.9040
# 7377  49.1176
# 7378  50.8347
# 7379  51.7985
# 7380  51.6071

# %%
# tổng quan về dữ liệu
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
# shape của dữ liệu
df.shape
# Out:
# (7381, 8)

# %%
# thống kê dữ liệu
df.describe(include='all')
# Out:
#                    Place    ProductId      ProductName         UmId UmName  \
# count               7381  7381.000000             7381  7381.000000   7381
# unique                 4          NaN               52          NaN      9
# top     National Average          NaN  Bulgur - Retail          NaN     KG
# freq                2633          NaN              174          NaN   5636
# mean                 NaN   254.509687              NaN    15.252811    NaN
# std                  NaN   141.008599              NaN    25.276665    NaN
# min                  NaN    52.000000              NaN     5.000000    NaN
# 25%                  NaN   114.000000              NaN     5.000000    NaN
# 50%                  NaN   239.000000              NaN     5.000000    NaN
# 75%                  NaN   388.000000              NaN     5.000000    NaN
# max                  NaN   502.000000              NaN   102.000000    NaN
#
#               Month         Year        Price
# ...

# %%
# Giá trung bình của từng loại thực phẩm là bao nhiêu
df.groupby('ProductName')['Price'].mean()
# Out:
# ProductName
# Apples (red) - Retail                                       2.392193
# Apples - Retail                                             3.885039
# Bananas - Retail                                            8.224784
# Beans (white) - Retail                                      9.572830
# Bread (common) - Retail                                     4.463293
# Bread (pita) - Retail                                       2.404545
# Bulgur - Retail                                             3.516712
# Cabbage - Retail                                            1.723395
# Cauliflower - Retail                                        3.274868
# Cheese - Retail                                            25.522875
# Chickpeas - Retail                                         10.347860
# Cocoa (powder) - Retail                                    43.802339
# Coffee (instant) - Retail                                  43.295493
# ...

# %%
# Các đề xuất
# 1. Tìm hiểu về các loại thực phẩm nào được bán nhiều nhất
# 2. Doanh thu các năm
# 3. Top 10 sản phẩm có doanh thu cao nhất 
# 4. Phân tích doanh thu của các tháng trong mỗi năm
